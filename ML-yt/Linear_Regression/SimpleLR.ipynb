# %%
import pandas as pd
df = pd.read_csv('placement.csv')
import matplotlib.pyplot as plt
plt.scatter(df['cgpa'],df['package'])
plt.show()

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(df.iloc[:,0:1],df.iloc[:,-1],test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
ypred = lr.predict(xtest)
plt.scatter(df['cgpa'],df['package'])
plt.plot(xtrain,lr.predict(xtrain),c='g')
plt.plot(xtest,lr.predict(xtest),c='r')
plt.show()

# %%
m = lr.coef_
c = lr.intercept_  # intercept/offset
print(m,c)
# Out:
# [0.57889552] -1.0515188176235046
